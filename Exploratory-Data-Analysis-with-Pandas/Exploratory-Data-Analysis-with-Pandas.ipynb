# %% [markdown]
# # Exploratory Data Analysis with Pandas

# %% [markdown]
# #### Memanggil library di Python

# %%
import pandas as pd

# %% [markdown]
# #### Membaca file CSV sebagai data frame

# %%
order = pd.read_csv('order.csv')
order
# Out:
#                                order_id  quantity  \
# 0      2e7a8482f6fb09756ca50c10d7bfc047         2
# 1      2e7a8482f6fb09756ca50c10d7bfc047         1
# 2      e5fa5a7210941f7d56d0208e4e071d35         1
# 3      3b697a20d9e427646d92567910af6d57         1
# 4      71303d7e93b399f5bcd537d124c0bcfa         1
# ...                                 ...       ...
# 49994  ec88157ad03aa203c3fdfe7bace5ab6b         1
# 49995  ed60085e92e2aa3debf49159deb34da7         1
# 49996  ed98c37d860890f940e2acd83629fdd1         2
# 49997  ed98c37d860890f940e2acd83629fdd1         1
# 49998  ede4ebbb6e36cbd377eabcc7f5229575         1
#
#                              product_id    price  \
# 0      f293394c72c9b5fafd7023301fc21fc2  1489000
# 1      c1488892604e4ba5cff5b4eb4d595400  1756000
# 2      f3c2d01a84c947b078e32bbef0718962  1707000
# 3      3ae08df6bcbfe23586dd431c40bddbb7  3071000
# 4      d2998d7ced12f83f9b832f33cf6507b6  3833000
# ...                                 ...      ...
# ...

# %% [markdown]
# #### Melihat struktur baris dan kolom dari data frame

# %%
order.shape
# Out:
# (49999, 12)

# %% [markdown]
# Data frame mempunyai 49999 baris dan 12 kolom.

# %% [markdown]
# #### Melihat preview data dari data frame

# %% [markdown]
# Secara default akan menampilkan 5 baris saja.

# %% [markdown]
# Menampilkan konten teratas dari data frame.

# %%
order.head(6)
# Out:
#                            order_id  quantity  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047         2
# 1  2e7a8482f6fb09756ca50c10d7bfc047         1
# 2  e5fa5a7210941f7d56d0208e4e071d35         1
# 3  3b697a20d9e427646d92567910af6d57         1
# 4  71303d7e93b399f5bcd537d124c0bcfa         1
# 5  be5bc2f0da14d8071e2d45451ad119d9         1
#
#                          product_id    price  \
# 0  f293394c72c9b5fafd7023301fc21fc2  1489000
# 1  c1488892604e4ba5cff5b4eb4d595400  1756000
# 2  f3c2d01a84c947b078e32bbef0718962  1707000
# 3  3ae08df6bcbfe23586dd431c40bddbb7  3071000
# 4  d2998d7ced12f83f9b832f33cf6507b6  3833000
# 5  fd7fd78fd3cbc1b0a6370a7909c0a629  1480000
#
#                           seller_id  freight_value  \
# 0  1554a68530182680ad5c8b042c3ab563          28000
# 1  1554a68530182680ad5c8b042c3ab563          45000
# 2  a425f92c199eb576938df686728acd20         174000
# 3  522620dcb18a6b31cd7bdf73665113a9         154000
# 4  25e6ffe976bd75618accfe16cefcbd0d         147000
# ...

# %% [markdown]
# Menampilkan konten terbawah dari data frame.

# %%
order.tail(6)
# Out:
#                                order_id  quantity  \
# 49993  e821c71ba6efed0813bbc0a01a95f24d         1
# 49994  ec88157ad03aa203c3fdfe7bace5ab6b         1
# 49995  ed60085e92e2aa3debf49159deb34da7         1
# 49996  ed98c37d860890f940e2acd83629fdd1         2
# 49997  ed98c37d860890f940e2acd83629fdd1         1
# 49998  ede4ebbb6e36cbd377eabcc7f5229575         1
#
#                              product_id    price  \
# 49993  f9259c9e7c0f12c70f7a81409680a5ff   342000
# 49994  165f86fe8b799a708a20ee4ba125c289  3077000
# 49995  6e835aea84ae8eb68b8c14878dd43b30  1277000
# 49996  aca2eb7d00ea1a7b8ebd4e68314663af   486000
# 49997  aca2eb7d00ea1a7b8ebd4e68314663af   830000
# 49998  2b0ee2d07306f7c9ac55a43166e9bb4b   215000
#
#                               seller_id  freight_value  \
# 49993  c68fb906c8f4b4b946d8386bfa6e5467         173000
# 49994  7ddcbb64b5bc1ef36ca8c151f6ec77df         172000
# 49995  4d6d651bd7684af3fffabd5f08d12e5a         130000
# ...

# %% [markdown]
# Menampilkan sebagian kolom (kolom 'price' dan 'product_category_name') dari konten teratas pada data frame.

# %%
order[['price', 'product_category_name']].head()
# Out:
#      price product_category_name
# 0  1489000               fashion
# 1  1756000            automotive
# 2  1707000                  toys
# 3  3071000             utilities
# 4  3833000               fashion

# %% [markdown]
# #### Statistik deskriptif

# %% [markdown]
# Secara umum function describe() secara otomatis memberikan summary statistik untuk kolom numerik dan mengabaikan kolom category.

# %%
order.describe()
# Out:
#            quantity         price  freight_value  product_weight_gram
# count  49999.000000  4.999900e+04   49999.000000         49980.000000
# mean       1.197484  2.607784e+06  104521.390428          2201.830892
# std        0.722262  1.388312e+06   55179.844962          3929.896875
# min        1.000000  2.000000e+05    9000.000000            50.000000
# 25%        1.000000  1.410500e+06   57000.000000           300.000000
# 50%        1.000000  2.610000e+06  104000.000000           800.000000
# 75%        1.000000  3.810000e+06  152000.000000          1850.000000
# max       21.000000  5.000000e+06  200000.000000         40425.000000

# %% [markdown]
# Menampilkan summary statistik untuk kolom category.

# %%
order.describe(include = 'object')
# Out:
#                                 order_id                        product_id  \
# count                              49999                             49999
# unique                             42694                             16866
# top     8272b63d03f5f79c56e9e4120aec44ef  99a4788cb24856965c36a24e339b6058
# freq                                  21                               366
#
#                                seller_id                       customer_id  \
# count                              49999                             49999
# unique                              1777                             42694
# top     4a3ca9315b744ce9f8e9374361493884  fc3d1daec319d62d49bfb5e1f83123e9
# freq                                1236                                21
#
#        order_status purchase_date     payment_type product_category_name
# count         49999         49999            49999                 49999
# ...

# %% [markdown]
# Menampilkan summary statistik dari semua kolom (kolom numerik dan category).

# %%
order.describe(include = 'all')
# Out:
#                                 order_id      quantity  \
# count                              49999  49999.000000
# unique                             42694           NaN
# top     8272b63d03f5f79c56e9e4120aec44ef           NaN
# freq                                  21           NaN
# mean                                 NaN      1.197484
# std                                  NaN      0.722262
# min                                  NaN      1.000000
# 25%                                  NaN      1.000000
# 50%                                  NaN      1.000000
# 75%                                  NaN      1.000000
# max                                  NaN     21.000000
#
#                               product_id         price  \
# count                              49999  4.999900e+04
# unique                             16866           NaN
# top     99a4788cb24856965c36a24e339b6058           NaN
# freq                                 366           NaN
# ...

# %%
print(f"mean price = {order.loc[:, 'price'].mean()}")
# Out:
# mean price = 2607783.9156783135

# %%
print(f"median price = {order.loc[:, 'price'].median()}")
# Out:
# median price = 2610000.0

# %%
print(f"mode price =\n{(order.loc[:, 'price'].mode())}")
# Out:
# mode price =
# 0    3174000
# 1    3627000
# Name: price, dtype: int64

# %% [markdown]
# #### Membuat histogram

# %%
order['price'].plot(figsize = (4, 5), kind = 'hist', bins = 15)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# #### Standar deviasi

# %%
print(f"standar deviasi product weight gram = {order.loc[:, 'product_weight_gram'].std()}")
# Out:
# standar deviasi product weight gram = 3929.8968753726213

# %% [markdown]
# #### Varians

# %%
print(f"varians product weight gram = {order.loc[:, 'product_weight_gram'].var()}")
# Out:
# varians product weight gram = 15444089.451063491

# %% [markdown]
# #### Interquartile range (IQR)

# %%
q1 = order['product_weight_gram'].quantile(0.25)
q3 = order['product_weight_gram'].quantile(0.75)
iqr = q3 - q1
print(f'product weight gram:\nQ1 = {q1}, Q3 ={q3}, dan IQR ={iqr}')
# Out:
# product weight gram:
# Q1 = 300.0, Q3 =1850.0, dan IQR =1550.0

# %% [markdown]
# #### Rename kolom data frame

# %% [markdown]
# Melakukan rename kolom dari 'freight_value' menjadi 'shipping_cost'.

# %%
order.rename(columns = {'freight_value': 'shipping_cost'}, inplace = True)
order
# Out:
#                                order_id  quantity  \
# 0      2e7a8482f6fb09756ca50c10d7bfc047         2
# 1      2e7a8482f6fb09756ca50c10d7bfc047         1
# 2      e5fa5a7210941f7d56d0208e4e071d35         1
# 3      3b697a20d9e427646d92567910af6d57         1
# 4      71303d7e93b399f5bcd537d124c0bcfa         1
# ...                                 ...       ...
# 49994  ec88157ad03aa203c3fdfe7bace5ab6b         1
# 49995  ed60085e92e2aa3debf49159deb34da7         1
# 49996  ed98c37d860890f940e2acd83629fdd1         2
# 49997  ed98c37d860890f940e2acd83629fdd1         1
# 49998  ede4ebbb6e36cbd377eabcc7f5229575         1
#
#                              product_id    price  \
# 0      f293394c72c9b5fafd7023301fc21fc2  1489000
# 1      c1488892604e4ba5cff5b4eb4d595400  1756000
# 2      f3c2d01a84c947b078e32bbef0718962  1707000
# 3      3ae08df6bcbfe23586dd431c40bddbb7  3071000
# 4      d2998d7ced12f83f9b832f33cf6507b6  3833000
# ...                                 ...      ...
# ...

# %% [markdown]
# #### Groupby

# %%
order['price'].groupby(order['payment_type']).mean()
# Out:
# payment_type
# credit card        2.600706e+06
# debit card         2.611974e+06
# e-wallet           2.598562e+06
# virtual account    2.619786e+06
# Name: price, dtype: float64

# %% [markdown]
# Menggunakan kolom 'payment_type' sebagai aggregate dan kemudian menghitung mean dari kolom 'price' pada setiap aggregate tersebut.

# %% [markdown]
# #### Sorting

# %% [markdown]
# Secara ascending.

# %%
order.sort_values(by = 'price',)
# Out:
#                                order_id  quantity  \
# 11939  64619901c45fba79638d666058bf6be6         1
# 42166  54220fcc516cabe9ec84b210c0765ef2         1
# 42452  9960ee97c2f8d801a200a01893b3942f         1
# 42025  36cdcd48e9697951eef9c32ef39dc9f3         1
# 33786  0d9e86e02c1a823b20c03ea29d616607         1
# ...                                 ...       ...
# 3976   f343624eab419250ad81f1ce6be22c93         1
# 21072  c8947a583ab9791a5a9d02384cb84302         1
# 41958  2711089c7fec59d4dc8483e3c6a12fa3         1
# 22618  a767765cf25c6fcfd8307499da9205d2         1
# 47074  f6134169ca6f0cdfbe6458ebb5731613         1
#
#                              product_id    price  \
# 11939  06c6e01186af8b98ee1fc9e01f9471e9   200000
# 42166  1166bc797ddf5fb009c376d133f61204   200000
# 42452  db5efde3ad0cc579b130d71c4b2db522   200000
# 42025  de75785dc5be712c4d4ed4ec5b422ce1   200000
# 33786  f93213a23c50edc16c27b96333f734dc   200000
# ...                                 ...      ...
# ...

# %% [markdown]
# Secara descending.

# %%
order.sort_values(by = 'price', ascending = False)
# Out:
#                                order_id  quantity  \
# 37085  d7b2d3b902441cf3dd12cd125533217d         1
# 41958  2711089c7fec59d4dc8483e3c6a12fa3         1
# 3976   f343624eab419250ad81f1ce6be22c93         1
# 21072  c8947a583ab9791a5a9d02384cb84302         1
# 47074  f6134169ca6f0cdfbe6458ebb5731613         1
# ...                                 ...       ...
# 33786  0d9e86e02c1a823b20c03ea29d616607         1
# 42166  54220fcc516cabe9ec84b210c0765ef2         1
# 31745  59a19c83ff825948739dd1601cc107b6         1
# 42452  9960ee97c2f8d801a200a01893b3942f         1
# 11939  64619901c45fba79638d666058bf6be6         1
#
#                              product_id    price  \
# 37085  35afc973633aaeb6b877ff57b2793310  5000000
# 41958  7c1bd920dbdf22470b68bde975dd3ccf  5000000
# 3976   777d2e438a1b645f3aec9bd57e92672c  5000000
# 21072  f8cfb63e323be2e1c4172f255d61843d  5000000
# 47074  2ea92fab7565c4fe9f91a5e4e1756258  5000000
# ...                                 ...      ...
# ...
